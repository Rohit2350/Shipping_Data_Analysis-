# %% [markdown]
# # **<span style='color:	#de831e'>Data Analysis of a Shipping Data Company</span>**

# %% [markdown]
# ****

# %% [markdown]
# ## 	<span style='color:#f44336'> Work Summary </span>

# %% [markdown]
# ### <span style='font-family:Helvitica'><span style='color:Red'>Summary </span>
# >> 1. Around 40% of packages were delivered late irrespective of their sizes and and price. <br>
# >> 2.Transportation by ships is very high after the ships most used transport is road transport. <br>
# >> 3.Discount offered & weight in grams shows a skewed distrubution. <br>
# >> 4.According to the cluster map there is + ve realtion between cost of product & customer calls so as the price of the product      increased the customer calls are also increased

# %% [markdown]
# ***

# %% [markdown]
# ## **<span style='color:#039d9e'>Data Collection</span>**

# %% [markdown]
# ###### The Data CSV file was Obtained from Kaggle and all the data credit goes to the author Prachi Goplani
# ###### Link for the dataset is given here (https://www.kaggle.com/datasets/prachi13/customer-analytics)

# %% [markdown]
# ##    **<span style='color:#039d9e'>Understanding the Data</span>**

# %% [markdown]
# The dataset used for model building has 10999 observations of 12 variables.
# The data contains the following information:
#
# ID: ID Number of Customers.
# Warehouse block: The Company have big Warehouse which is divided in to block such as A,B,C,D,E.
# Mode of shipment:The Company Ships the products in multiple way such as Ship, Flight and Road.
# Customer care calls: The number of calls made from enquiry for enquiry of the shipment.
# Customer rating: The company has rated from every customer. 1 is the lowest (Worst), 5 is the highest (Best).
# Cost of the product: Cost of the Product in US Dollars.
# Prior purchases: The Number of Prior Purchase.
# Product importance: The company has categorized the product in the various parameter such as low, medium, high.
# Gender: Male and Female.
# Discount offered: Discount offered on that specific product.
# Weight in gms: It is the weight in grams.
# Reached on time: It is the target variable, where 1 Indicates that the product has NOT reached on time and
# 0 indicates it has reached on time.

# %% [markdown]
# ***

# %% [markdown]
# ## **<span style='color:#039d9e'>Importing Libraries</span>**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("shipping_data.csv")

# %%
df.set_index("ID", inplace=True)

# %%
df['Warehouse_Block']=df['Warehouse_block'].replace(["F"],["E"],inplace=True)

# %% [markdown]
# ## **<span style='color:#039d9e'>Understanding the Data</span>**

# %%
df.head(5)
# Out:
#    Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# ID
# 1                D           Flight                    4                2
# 2                E           Flight                    4                5
# 3                A           Flight                    2                2
# 4                B           Flight                    3                3
# 5                C           Flight                    2                2
#
#     Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# ID
# 1                   177                3                low      F
# 2                   216                2                low      M
# 3                   183                4                low      M
# 4                   176                4             medium      M
# 5                   184                3             medium      F
#
#     Discount_offered  Weight_in_gms  Reached.on.Time_Y.N Warehouse_Block
# ID
# ...

# %%
df.isnull().sum()
# Out:
# Warehouse_block            0
# Mode_of_Shipment           0
# Customer_care_calls        0
# Customer_rating            0
# Cost_of_the_Product        0
# Prior_purchases            0
# Product_importance         0
# Gender                     0
# Discount_offered           0
# Weight_in_gms              0
# Reached.on.Time_Y.N        0
# Warehouse_Block        10999
# dtype: int64

# %%
df['Warehouse_block'].value_counts()
# Out:
# E    3666
# D    1834
# A    1833
# B    1833
# C    1833
# Name: Warehouse_block, dtype: int64

# %%
df['Mode_of_Shipment'].value_counts()
# Out:
# Ship      7462
# Flight    1777
# Road      1760
# Name: Mode_of_Shipment, dtype: int64

# %%
df['Customer_care_calls'].value_counts()
# Out:
# 4    3557
# 3    3217
# 5    2328
# 6    1013
# 2     638
# 7     246
# Name: Customer_care_calls, dtype: int64

# %%
df['Customer_rating'].value_counts()
# Out:
# 3    2239
# 1    2235
# 4    2189
# 5    2171
# 2    2165
# Name: Customer_rating, dtype: int64

# %%
df['Cost_of_the_Product'].value_counts()
# Out:
# 245    110
# 257    109
# 260    106
# 254    101
# 264    100
#       ...
# 107      5
# 99       5
# 120      5
# 96       5
# 122      4
# Name: Cost_of_the_Product, Length: 215, dtype: int64

# %%
df['Prior_purchases'].value_counts()
# Out:
# 3     3955
# 2     2599
# 4     2155
# 5     1287
# 6      561
# 10     178
# 7      136
# 8      128
# Name: Prior_purchases, dtype: int64

# %%
df['Product_importance'].value_counts()
# Out:
# low       5297
# medium    4754
# high       948
# Name: Product_importance, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# F    5545
# M    5454
# Name: Gender, dtype: int64

# %%
df["Discount_offered"].value_counts()
# Out:
# 10    860
# 2     858
# 6     849
# 9     845
# 3     840
#      ...
# 65     36
# 26     36
# 42     35
# 25     34
# 30     34
# Name: Discount_offered, Length: 65, dtype: int64

# %%
df["Weight_in_gms"].value_counts()
# Out:
# 4883    12
# 1145    10
# 5783    10
# 4741    10
# 5672    10
#         ..
# 1425     1
# 3811     1
# 1609     1
# 2178     1
# 1098     1
# Name: Weight_in_gms, Length: 4034, dtype: int64

# %%
df['Reached.on.Time_Y.N'].value_counts()
# Out:
# 1    6563
# 0    4436
# Name: Reached.on.Time_Y.N, dtype: int64

# %%
df[(df['Warehouse_block']=='A')&(df['Reached.on.Time_Y.N']==0)].count()
# Out:
# Warehouse_block        758
# Mode_of_Shipment       758
# Customer_care_calls    758
# Customer_rating        758
# Cost_of_the_Product    758
# Prior_purchases        758
# Product_importance     758
# Gender                 758
# Discount_offered       758
# Weight_in_gms          758
# Reached.on.Time_Y.N    758
# Warehouse_Block          0
# dtype: int64

# %%
df[(df['Warehouse_block']=='B')&(df['Reached.on.Time_Y.N']==0)].count()
# Out:
# Warehouse_block        729
# Mode_of_Shipment       729
# Customer_care_calls    729
# Customer_rating        729
# Cost_of_the_Product    729
# Prior_purchases        729
# Product_importance     729
# Gender                 729
# Discount_offered       729
# Weight_in_gms          729
# Reached.on.Time_Y.N    729
# Warehouse_Block          0
# dtype: int64

# %%
df[(df['Warehouse_block']=='C')&(df['Reached.on.Time_Y.N']==0)].value_counts()
# Out:
# Series([], dtype: int64)

# %%
df[(df['Warehouse_block']=='D')&(df['Reached.on.Time_Y.N']==0)].value_counts()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# **Delays in the delivery of the packages is caused by the following warehouses**
#
# **A has delayed the 41.35% of its packages**
#
# **B has delayed the 39.77% of its packages**
#
# **C has delayed the 40.31% of its packages**
#
# **D has delayed the 40.26% of its packages**

# %% [markdown]
# ## **<span style='color:#039d9e'>Visual Representation</span>**

# %% [markdown]
#  **<span style='color:red'>Plotting a histogram fro each Numerical Attribute</span>**

# %%
df.hist(bins=50,figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  **<span style='color:red'>Scatter Plot</span>**

# %%
scatter_matrix(df,marker="o",figsize=(15,15),hist_kwds={'bins':20},s=60, alpha=.8)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  **<span style='color:red'>Showing the counts with categories for the below coulmns</span>**

# %%
columns = ["Warehouse_block", "Mode_of_Shipment", "Customer_care_calls", 
"Customer_rating", "Prior_purchases", "Product_importance", "Gender", "Reached.on.Time_Y.N", "Discount_offered" ]
plt.figure(figsize = (15, 20))
plotnumber = 1
for i in range(len(columns)):
    if plotnumber <= 10:
        ax = plt.subplot(5, 2, plotnumber)
        sns.countplot(x = columns[i],ax=ax, data = df)
    plotnumber += 1
    plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**
# **1- Males count are almost the same like females**
# **2- Number of items reached on time is bigger**
# **3- Number of product importance Low and Medium are bigger than high**
# **4- Warehouse F is the highest**
# **5- Movement by ship is the highest**
# **6- Discount_offered and Weight_in_gms shows skewed distribution**

# %% [markdown]
#  **<span style='color:red'>Explore the relation between Reached on time and other attributes</span>**

# %%
columns = ["Warehouse_block", "Mode_of_Shipment", "Customer_care_calls", 
"Customer_rating", "Prior_purchases", "Product_importance", "Gender"]
plt.figure(figsize = (15, 20))
plotnumber = 1
for i in range(len(columns)):
    if plotnumber <= 9:
        ax = plt.subplot(5, 2, plotnumber)
        sns.countplot( columns[i], hue ='Reached.on.Time_Y.N',  data =df, ax=ax)
    plotnumber += 1
plt.show()

# %% [markdown]
# **Conclusion:**
# ***1- Products delievered on time with ship more than Road or flight***
# ***2- Products delievered on time with the product imprtance of (low and medium) are more than High importance.***

# %% [markdown]
# **<span style='color:red'>The following graphical visualization shows the relation between the customer's rating and the product's costing.</span>**

# %%
sns.barplot(x="Customer_rating", y="Cost_of_the_Product", data=df,hue='Gender')
# Out:
# <AxesSubplot:xlabel='Customer_rating', ylabel='Cost_of_the_Product'>

# %% [markdown]
# **<span style='color:red'>The following graphical visualization shows the relation between the Mode of shipment and whether the product is reached on time to the customer. </span>**

# %%
sns.barplot(x="Mode_of_Shipment", y="Reached.on.Time_Y.N",data=df,palette="viridis")
# Out:
# <AxesSubplot:xlabel='Mode_of_Shipment', ylabel='Reached.on.Time_Y.N'>

# %% [markdown]
# **<span style='color:red'>The following graphical visualization shows the relation between the gender and the product's costing</span>**

# %%
sns.barplot(x="Gender",y="Cost_of_the_Product",data=df,palette="rocket")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Cost_of_the_Product'>

# %% [markdown]
# **The following graphical visualization shows the relation between the different Warehouse blocks and the products reached on the time. This shows which warehouse block has performed well in the delivering the product on time.**

# %% [markdown]
# **<span style='color:red'> Bar-Plot</span>**

# %%
sns.barplot(x='Warehouse_block', y='Reached.on.Time_Y.N', data=df, palette='Spectral')
# Out:
# <AxesSubplot:xlabel='Warehouse_block', ylabel='Reached.on.Time_Y.N'>

# %% [markdown]
# **This Following Visualization shows the realtion between customer rating and prior purchase**

# %%
sns.barplot(x='Customer_rating',y='Prior_purchases',data=df, palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='Customer_rating', ylabel='Prior_purchases'>

# %% [markdown]
# **<span style='color:red'>Joint Plot</span>**

# %% [markdown]
# **The graphical representation below shows us the relation between the weight of the product and the cost of the product and by observing it we can see that as the lower the weight higher is the cost. Even though their are certain products which weigh higher and also cost high.**

# %%
sns.jointplot(x="Weight_in_gms", y="Cost_of_the_Product", data=df, kind='hex',palette='rocket')

# %% [markdown]
# **Joint Plot**

# %%
sns.jointplot(x="Weight_in_gms", y="Cost_of_the_Product", data=df, hue="Weight_in_gms")

# %% [markdown]
# **<span style="color:red">Cluster Map</span>**

# %%
sns.clustermap(df.corr(),annot=True,cmap='Spectral')

# %% [markdown]
# <b>Observations:</b>
#
# <b>1- There is psoitive relation between Discount offered and Reached on time
# 2- There is slight positive relation between Reached on time and Gender, warehouse and customer rating
# 3- There is positive relation between Cost of product and Customer care Calls
# 4- There is a slight positive relation between prior purchase and customer care calls
# 5- There is a slight positive relation between Customer rating and customer care calls
# 6- There is negative relation between weights in gms and customer care calls
# 7- There is negative relation between weights in gms and discount offered</b>
#
# <b>After observing the following the study of the provided data shows that the majority of the products are delivered by the ship and then the next mode of transport used most after the ships are roads.</b>

# %% [markdown]
# **Other way of visulization the correeltation with Reached on time to consider also Dicsount_Offered and Weights**

# %%
plt.figure(figsize=(10,6))
df[df['Mode_of_Shipment']=='Flight']['Cost_of_the_Product'].hist(alpha=0.5,color='blue',bins=30,label='Flight')
df[df['Mode_of_Shipment']=='Road']['Cost_of_the_Product'].hist(alpha=0.5,color='red',bins=30,label='Road')
df[df['Mode_of_Shipment']=='Ship']['Cost_of_the_Product'].hist(alpha=0.5,color='grey',bins=30,label='Ship')
plt.xlabel('COST')
plt.ylabel("Mode of Transport")
plt.legend()

# %% [markdown]
# **<span style="color:red">Pair Plot</span>**

# %%
sns.pairplot(data=df, hue = "Reached.on.Time_Y.N", palette = "RdBu")

# %% [markdown]
# <b>Observations:
# 1- More Items not reached on time with discount_offered higher than 30 and weight more than 4000 gms.
# 2- Check the possible outliers with Weights and Dicount offered since it shows skewed distribution</b>
